# %%
"hello, world"
# Out:
# 'hello, world'

# %%
print("hello, world")
# Out:
# hello, world

# %%
#Practice
math = 95
science = 95
english = 95
history = 94
MAPEH = 94

print ("First Grading: ")
print ("Math = ", math)
print ("Science = ", science)
print ("English = ", english)
print ("History = ", history)
print ("MAPEH = ", MAPEH)
# Out:
# First Grading:
# Math =  95
# Science =  95
# English =  95
# History =  94
# MAPEH =  94

# %%
Average = (Math + Science + English + History + MAPEH)/5
print ("Average = ", Average)
# Out:
# Average =  94.6

# %%
#Chapter 1: Exercise 1
print ("Hello world!") # I removed the [] and changed '' to ""
print ("Hello world!") # I removed the [], added ( and changed '' to ""
print ("Hello world!") # I removed the [] and changed ' into " and added "
print ("Hello world!") # I removed the [], removed '', changed into "" amd placed it between the text Hello world!
#Please note that single quotation or '' can be used in python but I prefer to use ""
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %%
#Chapter 1: Exercise 2
x = 6
print (x)
# I removed the []
# Out:
# 6

# %%
#Chapter 1: Exercise 3
x = 6
y = x * 7
print (y)
# I removed the [] and the rest of the code is correct
# Out:
# 42

# %%
#Chapter 2: Exercise 1
name = input ("Enter your name: ")
print ("Hello", name)
# Out:
# Enter your name: Loi
# Hello Loi

# %%
#Chapter 2: Exercise 2
hours = input ("Enter Hours: ")
rate = input ("Enter Rate: ")
grosspay = int (hours) * float (rate)
print ("Pay = ", grosspay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay =  96.25

# %%
#Chapter 2: Exercise 3
width = 17
height = 12.0

width//2
width/2.0
height/3
1 + 2 * 5
# Out:
# 11

# %%
#Chapter 2: Exercise 4
number = input ("Enter a number: ")
square = int (number)**2
print ("The square of ",number, "is ",square)
# Out:
# Enter a number: 3
# The square of  3 is  9

# %%
#Chapter 2: Challenge
celcius = input ("Enter temperature in celsius: ")
fahrenheit = (int (celcius) * 1.8) + 32
print ("The ",celcius, "in degree celcius is ",fahrenheit, "in degree fahrenheit.")
# Out:
# Enter temperature in celsius: 34
# The  34 in degree celcius is  93.2 in degree fahrenheit.
