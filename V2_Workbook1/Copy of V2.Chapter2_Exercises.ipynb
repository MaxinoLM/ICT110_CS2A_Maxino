# %%
#Loi Marie Maxino BSCS 2-A
#Chapter 2 - Variables, Expressions, and Statements
#Chapter 2: Exercise 1
name = input ("Enter your name: ")
print ("Hello", name)
# Out:
# Enter your name: Loi
# Hello Loi

# %%
#Chapter 2: Exercise 2
hours = input ("Enter Hours: ")
rate = input ("Enter Rate: ")
grosspay = int (hours) * float (rate)
print ("Pay = ", grosspay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay =  96.25

# %%
#Chapter 2: Exercise 3
width = 17
height = 12.0

width//2 #// is an integer division. value of width is 17, therefore 17 divided by 2 is 8 remainder 1, but integer division only gets the whole number which is 8
width/2.0 #this is a division with float point. so 17 divided by 2.0 is 8.5
height/3 #value of height which 12.0 divided by 3 is 4.0
1 + 2 * 5 #follow pemmdas and left to right manner
# Out:
# 11

# %%
#Chapter 2: Exercise 4
number = input ("Enter a number: ")
square = int (number)**2
print ("The square of ",number, "is ",square)
# Out:
# Enter a number: 3
# The square of  3 is  9

# %%
#Chapter 2: Challenge
celcius = input ("Enter temperature in celsius: ")
fahrenheit = (int (celcius) * 1.8) + 32
print ("The ",celcius, "in degree celcius is ",fahrenheit, "in degree fahrenheit.")
# Out:
# Enter temperature in celsius: 34
# The  34 in degree celcius is  93.2 in degree fahrenheit.
