# %%
#Chapter 3 - Conditional Execution
#Chapter 3: Exercise 1
x = 100
if x > 0 :
    print('Above 0')
elif x >  10 :
    print('Above 10') #this will never print regardless of the value of x
elif x > 50 :
    print('Above 50') #this will never print regardless of the value of x
elif x >  20 :
    print('Above 20') #this will never print regardless of the value of x
else :
    print('Something else') #this will never print regardless of the value of x

#error corrected
x =
if x >= 0 and x < 10 :
    print('Above 0')
elif x >=  10 and x < 20 :
    print('Above 10')
elif x > 50 :
    print('Above 50')
elif x >=  20 and x < 20:
    print('Above 20')
else :
    print('Something else')
# Out:
# Above 0
# Above 10

# %%
#Chapter 3: Exercise 2
hrs = int(input ("Enter Hours: "))
rt = int(input ("Enter Rate: "))

if hrs > 40 : #if an employee works for more than 40 hours then his/her rate will be 1.5 times higher than thos who worked 40 hours and below #pero meaning wla work-life balance charot
    pay =  int (hrs) * int (rt) * 1.5
    print ("Pay: ", float (pay))
elif hrs <= 40 :
    pay =  int (hrs) * int (rt)
    print ("Pay: ", float (pay))
# Out:
# Enter Hours: 41
# Enter Rate: 1
# Pay:  61.5

# %%
#Chapter 3: Challenge
score = float (input ("Enter score: "))

if score >= 97 and score <= 100 :
  print (1.0)
elif score >= 93 and score < 97 :
  print (1.25)
elif score >= 89 and score < 93 :
  print (1.5)
elif score >= 85 and score < 89 :
  print (1.75)
elif score >= 81 and score < 85 :
  print (2.0)
elif score >= 77 and score < 81 :
  print (2.25)
elif score >= 74 and score < 77 :
  print (2.5)
elif score >= 0 and score < 74 :
  print (3.0)
else:
  print ('invalid score')
# Out:
# Enter score: -1
# invalid score

# %%
#another code but with try and except
def get_grade(score):
    if 97 <= score <= 100:
        return 1.0
    elif 93 <= score < 97:
        return 1.25
    elif 89 <= score < 93:
        return 1.5
    elif 85 <= score < 89:
        return 1.75
    elif 81 <= score < 85:
        return 2.0
    elif 77 <= score < 81:
        return 2.25
    elif 74 <= score < 77:
        return 2.5
    elif 0 <= score < 74:
        return 3.0
    else:
        return None

def main():
    while True:
        try:
            score = float(input("Enter a score between 0 and 100: "))
            if 0 <= score <= 100:
                grade = get_grade(score)
                if grade is not None:
                    print("Grade:", grade)
                else:
                    print("Invalid score entered. Please try again.")
            else:
                print("Score must be between 0 and 100.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

if __name__ == "__main__":
    main()
