# %%
#Loi Marie Maxino BSCS 2-A
#Chapter 1 - Introduction
#Chapter 1: Exercise 1
print ("Hello world!") # no error
print ("Hello world!") # add (
print ("Hello world!") # add ' after !
print ("Hello world!") # double ' so I removed the excess ' after !
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %%
#Chapter 1: Exercise 2
#44 is the output
x = 43
x = x + 1 #value of x which is 43 plus 1, therefore 44
print(x)
# Out:
# 44

# %%
#Chapter 1: Exercise 3
#python is case sensitive, capital X is not a variable
x = 43
x = X + 1
print(x)
# Out:
# 42
